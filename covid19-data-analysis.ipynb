# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data=pd.read_csv(r"C:\Users\saiko\OneDrive\Desktop\python\Datascience\project2\covid19.csv")

# %%
data.head()
# Out:
#   date_of_interest  CASE_COUNT  PROBABLE_CASE_COUNT  HOSPITALIZED_COUNT  \
# 0       02/29/2020           1                    0                   1
# 1       03/01/2020           0                    0                   1
# 2       03/02/2020           0                    0                   2
# 3       03/03/2020           1                    0                   7
# 4       03/04/2020           5                    0                   2
#
#    DEATH_COUNT  CASE_COUNT_7DAY_AVG  ALL_CASE_COUNT_7DAY_AVG  \
# 0            0                    0                        0
# 1            0                    0                        0
# 2            0                    0                        0
# 3            0                    0                        0
# 4            0                    0                        0
#
#    HOSP_COUNT_7DAY_AVG  DEATH_COUNT_7DAY_AVG  BX_CASE_COUNT  ...  \
# 0                    0                     0              0  ...
# ...

# %%
data.columns
# Out:
# Index(['date_of_interest', 'CASE_COUNT', 'PROBABLE_CASE_COUNT',
#        'HOSPITALIZED_COUNT', 'DEATH_COUNT', 'CASE_COUNT_7DAY_AVG',
#        'ALL_CASE_COUNT_7DAY_AVG', 'HOSP_COUNT_7DAY_AVG',
#        'DEATH_COUNT_7DAY_AVG', 'BX_CASE_COUNT', 'BX_PROBABLE_CASE_COUNT',
#        'BX_HOSPITALIZED_COUNT', 'BX_DEATH_COUNT', 'BX_CASE_COUNT_7DAY_AVG',
#        'BX_PROBABLE_CASE_COUNT_7DAY_AVG', 'BX_ALL_CASE_COUNT_7DAY_AVG',
#        'BX_HOSPITALIZED_COUNT_7DAY_AVG', 'BX_DEATH_COUNT_7DAY_AVG',
#        'BK_CASE_COUNT', 'BK_PROBABLE_CASE_COUNT', 'BK_HOSPITALIZED_COUNT',
#        'BK_DEATH_COUNT', 'BK_CASE_COUNT_7DAY_AVG',
#        'BK_PROBABLE_CASE_COUNT_7DAY_AVG', 'BK_ALL_CASE_COUNT_7DAY_AVG',
#        'BK_HOSPITALIZED_COUNT_7DAY_AVG', 'BK_DEATH_COUNT_7DAY_AVG',
#        'MN_CASE_COUNT', 'MN_PROBABLE_CASE_COUNT', 'MN_HOSPITALIZED_COUNT',
#        'MN_DEATH_COUNT', 'MN_CASE_COUNT_7DAY_AVG',
#        'MN_PROBABLE_CASE_COUNT_7DAY_AVG', 'MN_ALL_CASE_COUNT_7DAY_AVG',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1718 entries, 0 to 1717
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date_of_interest                 1718 non-null   object
#  1   CASE_COUNT                       1718 non-null   int64
#  2   PROBABLE_CASE_COUNT              1718 non-null   int64
#  3   HOSPITALIZED_COUNT               1718 non-null   int64
#  4   DEATH_COUNT                      1718 non-null   int64
#  5   CASE_COUNT_7DAY_AVG              1718 non-null   int64
#  6   ALL_CASE_COUNT_7DAY_AVG          1718 non-null   int64
#  7   HOSP_COUNT_7DAY_AVG              1718 non-null   int64
#  8   DEATH_COUNT_7DAY_AVG             1718 non-null   int64
#  9   BX_CASE_COUNT                    1718 non-null   int64
#  10  BX_PROBABLE_CASE_COUNT           1718 non-null   int64
#  11  BX_HOSPITALIZED_COUNT            1718 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# date_of_interest                   0
# CASE_COUNT                         0
# PROBABLE_CASE_COUNT                0
# HOSPITALIZED_COUNT                 0
# DEATH_COUNT                        0
# CASE_COUNT_7DAY_AVG                0
# ALL_CASE_COUNT_7DAY_AVG            0
# HOSP_COUNT_7DAY_AVG                0
# DEATH_COUNT_7DAY_AVG               0
# BX_CASE_COUNT                      0
# BX_PROBABLE_CASE_COUNT             0
# BX_HOSPITALIZED_COUNT              0
# BX_DEATH_COUNT                     0
# BX_CASE_COUNT_7DAY_AVG             0
# BX_PROBABLE_CASE_COUNT_7DAY_AVG    0
# BX_ALL_CASE_COUNT_7DAY_AVG         0
# BX_HOSPITALIZED_COUNT_7DAY_AVG     0
# BX_DEATH_COUNT_7DAY_AVG            0
# BK_CASE_COUNT                      0
# BK_PROBABLE_CASE_COUNT             0
# BK_HOSPITALIZED_COUNT              0
# BK_DEATH_COUNT                     0
# BK_CASE_COUNT_7DAY_AVG             0
# BK_PROBABLE_CASE_COUNT_7DAY_AVG    0
# BK_ALL_CASE_COUNT_7DAY_AVG         0
# ...

# %%
sns.countplot(data=data,x='CASE_COUNT', color='red')
plt.show()

# %%
sns.countplot(data=data,x='HOSPITALIZED_COUNT', color='green')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1718 entries, 0 to 1717
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   date_of_interest                 1718 non-null   object
#  1   CASE_COUNT                       1718 non-null   int64
#  2   PROBABLE_CASE_COUNT              1718 non-null   int64
#  3   HOSPITALIZED_COUNT               1718 non-null   int64
#  4   DEATH_COUNT                      1718 non-null   int64
#  5   CASE_COUNT_7DAY_AVG              1718 non-null   int64
#  6   ALL_CASE_COUNT_7DAY_AVG          1718 non-null   int64
#  7   HOSP_COUNT_7DAY_AVG              1718 non-null   int64
#  8   DEATH_COUNT_7DAY_AVG             1718 non-null   int64
#  9   BX_CASE_COUNT                    1718 non-null   int64
#  10  BX_PROBABLE_CASE_COUNT           1718 non-null   int64
#  11  BX_HOSPITALIZED_COUNT            1718 non-null   int64
# ...

# %%
sns.catplot(data=data, x="HOSPITALIZED_COUNT", y="DEATH_COUNT")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.hist(data['HOSPITALIZED_COUNT'], bins=20, color='blue', edgecolor='black')

plt.title('Histogram of Daily COVID-19 Cases in NYC')
plt.xlabel('Daily Case Count')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
sns.relplot(data=data, x="CASE_COUNT", y="DEATH_COUNT")
plt.show()

# %%
# Plotting the time series plot for CASE_COUNT to visualize the trend of COVID-19 cases over time
plt.figure(figsize=(12, 6))
plt.plot(data['DEATH_COUNT'], color='Red', label='Daily Cases')

plt.title('Daily COVID-19 death Counts in NYC')
plt.xlabel('Days')
plt.ylabel('death Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the time series plot for CASE_COUNT to visualize the trend of COVID-19 cases over time
plt.figure(figsize=(12, 6))
plt.plot(data['CASE_COUNT'], color='purple', label='Daily Cases')

plt.title('Daily COVID-19 Case Counts in NYC')
plt.xlabel('Days')
plt.ylabel('Case Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotting the time series plot for CASE_COUNT to visualize the trend of COVID-19 cases over time
plt.figure(figsize=(12, 6))
plt.plot(data['HOSPITALIZED_COUNT'], color='blue', label='Daily Cases')

plt.title('Daily COVID-19 Hospitalized Counts in NYC')
plt.xlabel('Days')
plt.ylabel('hospitalized Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
sns.relplot(data=data, x="CASE_COUNT", y="DEATH_COUNT")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=data,
    x='HOSPITALIZED_COUNT',
    y='CASE_COUNT',
    hue=(data['CASE_COUNT'] > data['CASE_COUNT'].mean()),  # Color based on whether CASE_COUNT is above the mean
    palette=['blue', 'orange']
)
plt.title('CASE_COUNT vs HOSPITALIZED_COUNT')
plt.xlabel('HOSPITALIZED_COUNT')
plt.ylabel('CASE_COUNT')
plt.grid(True)
plt.legend(title="Above Avg CASE_COUNT", labels=["No", "Yes"])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.relplot(
    data=data,
    x='CASE_COUNT',
    y='DEATH_COUNT',
    hue=(data['CASE_COUNT'] > data['CASE_COUNT'].mean()), 
    kind='scatter',
    palette=['blue', 'green'],  # Two contrasting colors for differentiation
     height=6,
    aspect=1.5
)

plt.title('COVID-19 Daily Cases vs. Deaths in NYC ')
plt.xlabel('Daily Case Count')
plt.ylabel('Daily Death Count')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.relplot(
    data=data,
    x='CASE_COUNT',
    y='DEATH_COUNT',
    hue=(data['CASE_COUNT'] > data['CASE_COUNT'].mean()), 
    kind='line',
    palette=['blue', 'orange'],  # Two contrasting colors for differentiation
    height=6,
    aspect=1.5
)

plt.title('COVID-19 Daily Cases vs. Deaths in NYC ')
plt.xlabel('Daily Case Count')
plt.ylabel('Daily Death Count')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.relplot(
    data=data,
    x='HOSPITALIZED_COUNT',
    y='DEATH_COUNT',
    hue=(data['CASE_COUNT'] > data['CASE_COUNT'].mean()), 
    kind='line',
    palette=['blue', 'red'],  # Two contrasting colors for differentiation
    height=6,
    aspect=1.5
)

plt.title('COVID-19 Death vs.HOSPITALIZED in NYC ')
plt.xlabel('Daily HOSPITALIZED COUNT')
plt.ylabel('Daily Death Count')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.relplot(
    data=data,
    x='HOSPITALIZED_COUNT',
    y='DEATH_COUNT',
    hue=(data['CASE_COUNT'] > data['CASE_COUNT'].mean()), 
    kind='scatter',
    palette=['blue', 'orange'],  # Two contrasting colors for differentiation
    height=6,
    aspect=1.5
)

plt.title('COVID-19 Daily Cases vs.HOSPITALIZED in NYC ')
plt.xlabel('Daily HOSPITALIZED COUNT')
plt.ylabel('Daily Death Count')
plt.grid(True)
plt.show()

# %%
sns.relplot(data=data, x="CASE_COUNT", y="DEATH_COUNT")
plt.show()

# %%
sns.relplot(data=data, x="CASE_COUNT", y="QN_CASE_COUNT",kind="line")
plt.show()

# %%
sns.catplot(data=data, x="CASE_COUNT", y="QN_CASE_COUNT")
plt.show()

# %%
data.describe()
# Out:
#          CASE_COUNT  PROBABLE_CASE_COUNT  HOSPITALIZED_COUNT  DEATH_COUNT  \
# count   1718.000000          1718.000000         1718.000000  1718.000000
# mean    1733.444121           395.175204          128.073923    27.179278
# std     4123.020164           527.931219          207.829667    81.582566
# min        0.000000             0.000000            0.000000     0.000000
# 25%      314.250000            94.000000           34.000000     3.000000
# 50%      752.000000           271.500000           66.000000     7.000000
# 75%     1923.000000           518.750000          131.750000    17.000000
# max    55057.000000          5881.000000         1858.000000   831.000000
#
#        CASE_COUNT_7DAY_AVG  ALL_CASE_COUNT_7DAY_AVG  HOSP_COUNT_7DAY_AVG  \
# count          1718.000000              1718.000000          1718.000000
# mean           1733.320722              2128.448196           128.051222
# std            3805.594028              4262.569843           204.414857
# ...

# %%
data['date_of_interest'] = pd.to_datetime(data['date_of_interest'])
data.set_index('date_of_interest', inplace=True)
key_columns = ['CASE_COUNT', 'HOSPITALIZED_COUNT', 'DEATH_COUNT']
covid_summary = data[key_columns]
# Plotting the trends for cases, hospitalizations, and deaths
plt.figure(figsize=(14, 8))
plt.plot(covid_summary.index, covid_summary['CASE_COUNT'], label='Daily Cases', color='blue', alpha=0.6)
plt.plot(covid_summary.index, covid_summary['HOSPITALIZED_COUNT'], label='Daily Hospitalizations', color='orange', alpha=0.6)
plt.plot(covid_summary.index, covid_summary['DEATH_COUNT'], label='Daily Deaths', color='red', alpha=0.6)

# Enhancing plot aesthetics
plt.title('COVID-19 Daily Cases, Hospitalizations, and Deaths in NYC')
plt.xlabel('Date')
plt.ylabel('Counts')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
